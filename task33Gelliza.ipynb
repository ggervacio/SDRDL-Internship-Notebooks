# %% [markdown]
# # Task #33

# %% [markdown]
# #### "Which school accepted the most transfers?"

# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import pandas as pd
from  sdipylib.url import cache_url
pd.options.display.max_columns = 50

# %%
fn = cache_url('http://warehouse.sandiegodata.org/voiceofsandiego.org/d756fd2e-1480-4e30-a355-5e8abe46358b/sweetwater_transfers.csv')
sweetwater_transfers = pd.read_csv(fn)

# %%
sweetwater_transfers.head()
# Out:
#    id  year dest origin    status
# 0   1  2012  BVH    ORH  Approved
# 1   2  2012  BVH    ELH  Approved
# 2   3  2012  BVH    CPH  Approved
# 3   4  2012  BVH    CVH  Approved
# 4   5  2012  BVH    CVH  Approved
#
# [5 rows x 5 columns]

# %%
notsameschool = sweetwater_transfers.dest != sweetwater_transfers.origin
df=sweetwater_transfers[notsameschool]

# %%
df.head()
# Out:
#    id  year dest origin    status
# 0   1  2012  BVH    ORH  Approved
# 1   2  2012  BVH    ELH  Approved
# 2   3  2012  BVH    CPH  Approved
# 3   4  2012  BVH    CVH  Approved
# 4   5  2012  BVH    CVH  Approved
#
# [5 rows x 5 columns]

# %%
new = df.groupby(['dest', 'status']).size()
stat = pd.DataFrame(new)
stat
# Out:
#                     0
# dest  status
# BVH   Approved   1540
#       Denied      279
#       Pending      13
# BVM    Approved     1
#       Approved   1274
#       Denied      178
#       Pending      12
# CPH   Approved   1133
#       Denied       30
#       Pending       3
# CPM   Approved    463
#       Denied       13
#       Pending       1
# CVH   Approved   1011
#       Denied      242
#       Pending       8
# CVM   Approved   1289
#       Denied      142
#       Pending       5
# ELH   Approved   1679
#       Denied      248
#       Pending       7
# ELM   Approved    591
#       Denied      179
#       Pending       2
# GJH   Approved    398
#       Denied        8
#       Pending       2
# HTH   Approved   1482
#       Denied      184
#       Pending      11
# HTM   Approved   1793
#       Denied      218
#       Pending       7
# MOH   Approved   2344
#       Denied       87
#       Pending       8
# MOM   Approved    499
#       Denied       47
#       Pending       1
# ...

# %% [markdown]
# This is what I have so far - it doesn't look like much because I was playing around with this a lot and it was pretty messy, so for the purposes of sharing what I have done so far, I cleaned it up.
#
# By looking at this table as it is now, I can see that ORH has approved the most transfer students.
#
# I'm still trying to rearrage the table so that 'Approved', 'Denied', and 'Pending' are the columns, so that it will look more clean and easier to read. I tried to use the pd.pivot command but I haven't been able to get it right yet. Also, I think after the table is rearranged, I hope to sort the table by number of approved transfers.
#
# Any tips or suggestions would be great :)
#
# Also note: I'm not sure why there are two 'Approved' sections for BVM.
